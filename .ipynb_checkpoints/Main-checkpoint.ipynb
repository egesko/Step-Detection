# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
import tensorflow as tf
import math
import sys

# %%
data1 = pd.read_csv("Data-4-30.csv",header=None).to_numpy()
data2 = pd.read_csv("Data-4-30-Daeyoo.csv",header=None).to_numpy()
data3 = pd.read_csv("Data-Ege-1.csv",header=None).to_numpy()
data4 = pd.read_csv("Data-Ege-2.csv",header=None).to_numpy()
data5 = pd.read_csv("Data-Daeyoo-1.csv",header=None).to_numpy()

# %%
data2.shape
# Out:
# (1452, 4)

# %%
full_data = np.append(data1,data2,axis=0)
full_data = np.append(full_data,data3,axis=0)
full_data = np.append(full_data,data4,axis=0)
full_data = np.append(full_data,data5,axis=0)

# %%
full_data.shape
# Out:
# (8065, 4)

# %% [markdown]
# ### Interactive plot of Z-axis and Y

# %%
#%matplotlib widget

print("Red = Walking, Blue = Not Walking")
plt.figure(figsize=(12,10))

testY = full_data[:,3]


for i in range(len(full_data)):
    if(testY[i] == 1):
        plt.axvspan(i-1, i, facecolor='w', alpha=0.3)
    else:
        plt.axvspan(i-1, i, facecolor='k', alpha=0.3)


plt.plot(full_data[:,0]-np.mean(full_data[:,0]),color="k",label="X")
plt.plot(full_data[:,1]-np.mean(full_data[:,1]),color="y",label="Y")
plt.plot(full_data[:,2]-np.mean(full_data[:,2]),label="Z")
#plt.plot(full_data[:,3],label="Walking?")
plt.legend()
# Out:
# Red = Walking, Blue = Not Walking

# %% [markdown]
# # Seperate dataset into samples

# %%
def Prepare_Data(sampleLength,data):
    
    Y = data[:,3]
    X = data[:,0:3]
    
    
    Splitted_X = np.array(np.split(X, sampleLength))
    Splitted_Y = np.array(np.split(Y, np.ma.size(Y,axis=0)/sampleLength))
    
    #print(Splitted_Y.shape)
    
    
    
    
    finalX = np.reshape(Splitted_X,(np.ma.size(Splitted_X, axis=1),sampleLength,3))
    
    
    
    Output = np.round(np.sum(Splitted_Y,axis=1)/sampleLength)
    
    
    
    return finalX,Output

# %%
np.set_printoptions(threshold=sys.maxsize)
i = 3
finalX,Output = Prepare_Data(i,full_data[0: math.floor(np.ma.size(full_data,axis=0)/i)*i,:])

print(finalX.shape)
print(Output.shape)
# Out:
# (2688, 3, 3)
# (2688,)

# %% [markdown]
# # Define Simple Vanilla Neural Network

# %%
def my_model(n):

    input_1 = keras.Input(shape = (n,))

    dense_1= Dense(100,activation = 'relu')(input_1)
    dense_2= Dense(100,activation = 'relu')(dense_1)
    dense_3= Dense(2,activation = 'softmax')(dense_2)

    model = keras.Model(inputs = input_1, outputs = dense_3)
    return model

# %% [markdown]
# # Training

# %%
plot_0=[]
plot_1=[]
plot_2=[]

plot_x=[]
for i in range(1,15):
    
    
    
    print("--------------------------------------------------------------")
    print(i)
    
    
    finalX , Output = Prepare_Data(i,full_data[0: math.floor(np.ma.size(full_data,axis=0)/i)*i,:])
    
    #print("1s: "+str(np.sum(Output,axis=0)/np.ma.size(Output, axis=0)))
    #print("0s: "+str((np.ma.size(Output, axis=0)-np.sum(Output,axis=0))/np.ma.size(Output, axis=0)))
    
    
    
    X = tf.random.shuffle(finalX[:,:,0])
    Y = tf.random.shuffle(finalX[:,:,1])
    Z = tf.random.shuffle(finalX[:,:,2])
    
    model = my_model(i)
    
    model.compile(
        loss=keras.losses.SparseCategoricalCrossentropy(),
        optimizer=keras.optimizers.Adam(),
        metrics=["accuracy"]
    )
    
    history_train0 = model.fit(X,Output,epochs = 10,validation_split=0.3,batch_size=16,verbose=0)
    history_train1 = model.fit(Y,Output,epochs = 10,validation_split=0.3,batch_size=16,verbose=0)
    history_train2 = model.fit(Z,Output,epochs = 10,validation_split=0.3,batch_size=16,verbose=0)
    
    print("X axis validation accuracy: "+str(history_train0.history['val_accuracy'][-1]))
    print("Y axis validation accuracy: "+str(history_train1.history['val_accuracy'][-1]))
    print("Z axis validation accuracy: "+str(history_train2.history['val_accuracy'][-1]))
    
    
    plot_x.append(i)
    
    plot_0.append(history_train0.history['val_accuracy'][-1])
    plot_1.append(history_train1.history['val_accuracy'][-1])
    plot_2.append(history_train2.history['val_accuracy'][-1])
# Out:
# --------------------------------------------------------------
# 1
# X axis validation accuracy: 0.7371900677680969
# Y axis validation accuracy: 0.7371900677680969
# Z axis validation accuracy: 0.7371900677680969
# --------------------------------------------------------------
# 2
# X axis validation accuracy: 0.7603305578231812
# Y axis validation accuracy: 0.7603305578231812
# Z axis validation accuracy: 0.7603305578231812
# --------------------------------------------------------------
# 3
# X axis validation accuracy: 0.7372986078262329
# Y axis validation accuracy: 0.7372986078262329
# Z axis validation accuracy: 0.7311028242111206
# --------------------------------------------------------------
# 4
# X axis validation accuracy: 0.7504132390022278
# Y axis validation accuracy: 0.7520661354064941
# Z axis validation accuracy: 0.7504132390022278
# --------------------------------------------------------------
# 5
# X axis validation accuracy: 0.7355371713638306
# Y axis validation accuracy: 0.7355371713638306
# Z axis validation accuracy: 0.7396694421768188
# --------------------------------------------------------------
# 6
# X axis validation accuracy: 0.7599009871482849
# Y axis validation accuracy: 0.7648515105247498
# Z axis validation accuracy: 0.7599009871482849
# --------------------------------------------------------------
# 7
# X axis validation accuracy: 0.7601156234741211
# Y axis validation accuracy: 0.7572254538536072
# Z axis validation accuracy: 0.7572254538536072
# --------------------------------------------------------------
# 8
# X axis validation accuracy: 0.7656765580177307
# Y axis validation accuracy: 0.7623762488365173
# Z axis validation accuracy: 0.7491748929023743
# --------------------------------------------------------------
# 9
# X axis validation accuracy: 0.732342004776001
# Y axis validation accuracy: 0.7286245226860046
# Z axis validation accuracy: 0.7211896181106567
# --------------------------------------------------------------
# 10
# X axis validation accuracy: 0.7644628286361694
# Y axis validation accuracy: 0.7479338645935059
# Z axis validation accuracy: 0.7272727489471436
# --------------------------------------------------------------
# 11
# X axis validation accuracy: 0.699999988079071
# Y axis validation accuracy: 0.7272727489471436
# Z axis validation accuracy: 0.7045454382896423
# --------------------------------------------------------------
# 12
# X axis validation accuracy: 0.7475247383117676
# Y axis validation accuracy: 0.7623762488365173
# Z axis validation accuracy: 0.7524752616882324
# --------------------------------------------------------------
# 13
# X axis validation accuracy: 0.7150537371635437
# Y axis validation accuracy: 0.7419354915618896
# Z axis validation accuracy: 0.7365591526031494
# --------------------------------------------------------------
# 14
# X axis validation accuracy: 0.6820809245109558
# Y axis validation accuracy: 0.7456647157669067
# Z axis validation accuracy: 0.7514451146125793

# %%
fig = plt.figure(figsize=(12,10))
plt.plot(plot_x,plot_0)
plt.plot(plot_x,plot_1)
plt.plot(plot_x,plot_2)

# %%
finalX , Output = Prepare_Data(6,full_data[0: math.floor(np.ma.size(full_data,axis=0)/6)*6,:])
    

X = tf.random.shuffle(finalX[:,:,0])
Y = tf.random.shuffle(finalX[:,:,1])
Z = tf.random.shuffle(finalX[:,:,2])

model = my_model(6)

model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(),
    optimizer=keras.optimizers.Adam(),
    metrics=["accuracy"]
)

history_train = model.fit(Z,Output,epochs = 15,validation_split=0.3,batch_size=16,verbose=1)
# Out:
# Epoch 1/15
# 59/59 [==============================] - 0s 3ms/step - loss: 0.6051 - accuracy: 0.7170 - val_loss: 0.5632 - val_accuracy: 0.7673
# Epoch 2/15
# 59/59 [==============================] - 0s 2ms/step - loss: 0.6184 - accuracy: 0.7245 - val_loss: 0.5581 - val_accuracy: 0.7649
# Epoch 3/15
# 59/59 [==============================] - 0s 2ms/step - loss: 0.6059 - accuracy: 0.7181 - val_loss: 0.5755 - val_accuracy: 0.7649
# Epoch 4/15
# 59/59 [==============================] - 0s 2ms/step - loss: 0.6069 - accuracy: 0.7213 - val_loss: 0.5591 - val_accuracy: 0.7649
# Epoch 5/15
# 59/59 [==============================] - 0s 2ms/step - loss: 0.5911 - accuracy: 0.7213 - val_loss: 0.5557 - val_accuracy: 0.7624
# Epoch 6/15
# 59/59 [==============================] - 0s 2ms/step - loss: 0.5918 - accuracy: 0.7223 - val_loss: 0.5637 - val_accuracy: 0.7649
# Epoch 7/15
# 59/59 [==============================] - 0s 2ms/step - loss: 0.5887 - accuracy: 0.7223 - val_loss: 0.5557 - val_accuracy: 0.7673
# Epoch 8/15
# 59/59 [==============================] - 0s 2ms/step - loss: 0.5869 - accuracy: 0.7223 - val_loss: 0.5564 - val_accuracy: 0.7649
# Epoch 9/15
# 59/59 [==============================] - 0s 2ms/step - loss: 0.5865 - accuracy: 0.7234 - val_loss: 0.5642 - val_accuracy: 0.7624
# Epoch 10/15
# 59/59 [==============================] - 0s 3ms/step - loss: 0.5817 - accuracy: 0.7234 - val_loss: 0.5562 - val_accuracy: 0.7624
# Epoch 11/15
# 59/59 [==============================] - 0s 2ms/step - loss: 0.5825 - accuracy: 0.7223 - val_loss: 0.5750 - val_accuracy: 0.7649
# Epoch 12/15
# 59/59 [==============================] - 0s 2ms/step - loss: 0.5837 - accuracy: 0.7223 - val_loss: 0.5529 - val_accuracy: 0.7624
# Epoch 13/15
# 59/59 [==============================] - 0s 2ms/step - loss: 0.5830 - accuracy: 0.7245 - val_loss: 0.5605 - val_accuracy: 0.7649
# Epoch 14/15
# 59/59 [==============================] - 0s 2ms/step - loss: 0.5810 - accuracy: 0.7245 - val_loss: 0.5559 - val_accuracy: 0.7624
# Epoch 15/15
# 59/59 [==============================] - 0s 2ms/step - loss: 0.5806 - accuracy: 0.7255 - val_loss: 0.5592 - val_accuracy: 0.7723

# %%
model.save('my_model')
# Out:
# INFO:tensorflow:Assets written to: my_model\assets
